# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics

# %%
beer = pd.read_csv('beers.csv')

# %%
beer
# Out:
#       Unnamed: 0    abv    ibu    id  \
# 0              0  0.050    NaN  1436
# 1              1  0.066    NaN  2265
# 2              2  0.071    NaN  2264
# 3              3  0.090    NaN  2263
# 4              4  0.075    NaN  2262
# 5              5  0.077    NaN  2261
# 6              6  0.045    NaN  2260
# 7              7  0.065    NaN  2259
# 8              8  0.055    NaN  2258
# 9              9  0.086    NaN  2131
# 10            10  0.072    NaN  2099
# 11            11  0.073    NaN  2098
# 12            12  0.069    NaN  2097
# 13            13  0.085    NaN  1980
# 14            14  0.061   60.0  1979
# 15            15  0.060    NaN  2318
# 16            16  0.060    NaN  2170
# 17            17  0.060    NaN  2169
# 18            18  0.060    NaN  1502
# 19            19  0.082    NaN  1593
# 20            20  0.082    NaN  1592
# 21            21  0.099   92.0  1036
# 22            22  0.079   45.0  1024
# 23            23  0.079    NaN   976
# ...

# %%
plt.plot(beer['abv'], color='blue', alpha=0.5, label='ABV') 
plt.plot(beer['style'], color='red', alpha=0.5, label='Style') 
plt.plot(beer['ounces'], color='purple', alpha=0.5, label='Ounces') 
plt.legend(loc='upper right')
plt.ylabel('y')
plt.xlabel('x')
plt.title('Title')
plt.show()

# %%
print(beer.dtypes)
# Out:
# Unnamed: 0      int64
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %%
plt.plot(beer['abv'])

# %%
plt.plot(beer['style'])

# %%
plt.plot(beer['ounces'])

# %%
beer['style'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-bbd4c4818c45> in <module>()
# ----> 1 beer['style'].astype('float')
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
beer['style'].astype('str')
# Out:
# 0                  American Pale Lager
# 1              American Pale Ale (APA)
# 2                         American IPA
# 3       American Double / Imperial IPA
# 4                         American IPA
# 5                        Oatmeal Stout
# 6              American Pale Ale (APA)
# 7                      American Porter
# 8              American Pale Ale (APA)
# 9       American Double / Imperial IPA
# 10              Saison / Farmhouse Ale
# 11              Saison / Farmhouse Ale
# 12              Saison / Farmhouse Ale
# 13                         Belgian IPA
# 14             American Pale Ale (APA)
# 15                               Cider
# 16                               Cider
# 17                               Cider
# 18                               Cider
# 19                       Baltic Porter
# 20                              Tripel
# 21                 American Barleywine
# 22                       Winter Warmer
# 23                      American Stout
# ...

# %%
print(beer.dtypes)
# Out:
# Unnamed: 0      int64
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %%
beer.style.value_counts().head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-158645718cdf> in <module>()
# ----> 1 beer.style.value_counts().head(10)
#
# AttributeError: 'Styler' object has no attribute 'value_counts'

# %%
beer['style'].value_counts()
# Out:
# American IPA                           424
# American Pale Ale (APA)                245
# American Amber / Red Ale               133
# American Blonde Ale                    108
# American Double / Imperial IPA         105
# American Pale Wheat Ale                 97
# American Brown Ale                      70
# American Porter                         68
# Saison / Farmhouse Ale                  52
# Witbier                                 51
# Fruit / Vegetable Beer                  49
# Kölsch                                  42
# Hefeweizen                              40
# American Stout                          39
# American Pale Lager                     39
# Cider                                   37
# American Black Ale                      36
# German Pilsener                         36
# Märzen / Oktoberfest                    30
# Cream Ale                               29
# American Amber / Red Lager              29
# Czech Pilsener                          28
# ...

# %%
beer.loc[beer['style'].str.contains("Ale", na=False)] = 'Ale'

# %%
beer.loc[beer['style'].str.contains("Ale", na=False)] = 'Ale'
beer.loc[beer['style'].str.contains("Stout", na=False)] = 'Stout'
beer.loc[beer['style'].str.contains("Porter", na=False)] = 'Porter'
beer.loc[beer['style'].str.contains("Lager", na=False)] = 'Lager'
beer.loc[beer['style'].str.contains("Pilsner", na=False)] = 'Pilsner'
beer.loc[beer['style'].str.contains("Barleywine", na=False)] = 'Barleywine'
beer.loc[beer['style'].str.contains("IPA", na=False)] = 'IPA'

# %%
beer['style'].describe()
# Out:
# count     2405
# unique      48
# top        Ale
# freq       976
# Name: style, dtype: object

# %%
plot.boxplot(beer['style'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5a729e48e5af> in <module>()
# ----> 1 plot.boxplot(beer['style'])
#
# NameError: name 'plot' is not defined

# %%
beer.loc[beer['style'].str.contains("Ale", na=False)] = 'Ale'
beer.loc[beer['style'].str.contains("Stout", na=False)] = 'Stout'
beer.loc[beer['style'].str.contains("Porter", na=False)] = 'Porter'
beer.loc[beer['style'].str.contains("Lager", na=False)] = 'Lager'
beer.loc[beer['style'].str.contains("Pilsner", na=False)] = 'Pilsner'
beer.loc[beer['style'].str.contains("Barleywine", na=False)] = 'Barleywine'
beer.loc[beer['style'].str.contains("IPA", na=False)] = 'IPA'
beer.loc[beer['style'].str.contains("Kölsch", na=False)] = 'Kölsch'
beer.loc[beer['style'].str.contains("Hefeweizen", na=False)] = 'Hefeweizen'
beer.loc[beer['style'].str.contains("Saison", na=False)] = 'Saison'
beer.loc[beer['style'].str.contains("Cider", na=False)] = 'Cider'
beer.loc[beer['style'].str.contains("Oktoberfest", na=False)] = 'Oktoberfest'
beer.loc[beer['style'].str.contains("Bitter", na=False)] = 'Bitter'
beer.loc[beer['style'].str.contains("Shandy ", na=False)] = 'Shandy'
beer.loc[beer['style'].str.contains("Dunkelweizen", na=False)] = 'Dunkelweizen'

# %%
beer['style'].value_counts()
# Out:
# Ale                               976
# IPA                               558
# Lager                             158
# Stout                             100
# Porter                             74
# Witbier                            51
# Fruit / Vegetable Beer             49
# Kölsch                             42
# Hefeweizen                         40
# Cider                              37
# German Pilsener                    36
# Oktoberfest                        30
# Czech Pilsener                     28
# Pilsner                            27
# Bitter                             23
# Rye Beer                           18
# Winter Warmer                      15
# Altbier                            13
# Berliner Weissbier                 11
# Tripel                             11
# Gose                               10
# Herbed / Spiced Beer                9
# Schwarzbier                         9
# Doppelbock                          7
# Bock                                7
# ...

# %%
beer.loc[beer['style'].str.contains('Kristalweizen', 'Grisette', 'Other', 'Low Alcohol Beer', 'Flanders Oud Bruin', 'American Malt Liquor', 'Smoked Beer', 'Braggot', na=False)] = 'Other'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d41d2a756697> in <module>()
# ----> 1 beer.loc[beer['style'].str.contains('Kristalweizen', 'Grisette', 'Other', 'Low Alcohol Beer', 'Flanders Oud Bruin', 'American Malt Liquor', 'Smoked Beer', 'Braggot', na=False)] = 'Other'
#
# TypeError: contains() got multiple values for argument 'na'
