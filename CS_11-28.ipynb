# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics

# %%
bitcoin = pd.read_csv('bitcoin_price.csv')
ethereum = pd.read_csv('ethereum_price.csv')
ripple = pd.read_csv('ripple_price.csv')
nem = pd.read_csv('nem_price.csv')

# %%
bitcoin
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 0     Nov 07, 2017  7023.10  7253.32  7023.10  7144.38  2,326,340,000
# 1     Nov 06, 2017  7403.22  7445.77  7007.31  7022.76  3,111,900,000
# 2     Nov 05, 2017  7404.52  7617.48  7333.19  7407.41  2,380,410,000
# 3     Nov 04, 2017  7164.48  7492.86  7031.28  7379.95  2,483,800,000
# 4     Nov 03, 2017  7087.53  7461.29  7002.94  7207.76  3,369,860,000
# 5     Nov 02, 2017  6777.77  7367.33  6758.72  7078.50  4,653,770,000
# 6     Nov 01, 2017  6440.97  6767.31  6377.88  6767.31  2,870,320,000
# 7     Oct 31, 2017  6132.02  6470.43  6103.33  6468.40  2,311,380,000
# 8     Oct 30, 2017  6114.85  6214.99  6040.85  6130.53  1,772,150,000
# 9     Oct 29, 2017  5754.44  6255.71  5724.58  6153.85  2,859,040,000
# 10    Oct 28, 2017  5787.82  5876.72  5689.19  5753.09  1,403,920,000
# 11    Oct 27, 2017  5899.74  5988.39  5728.82  5780.90  1,710,130,000
# ...

# %%
print(bitcoin.dtypes)
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
bitcoin['Date'] = pd.to_datetime(bitcoin['Date'])

# %%
print(bitcoin.dtypes)
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume                object
# Market Cap            object
# dtype: object

# %%
bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','').astype(np.float64)
bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','').astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e1415c0ac831> in <module>()
# ----> 1 bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','').astype(np.float64)
#       2 bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','').astype(np.float64)
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','- = None','').astype(np.float64)
bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','- = None','').astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b2143fd3e50c> in <module>()
#       1 bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','- = None','').astype(np.float64)
# ----> 2 bitcoin['Volume'] = bitcoin['Volume'].str.replace(',','- = None','').astype(np.float64)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
#      53             return self.accessor_cls
# ...

# %%
for bitcoin in range(len(bitcoin['Volume'])):
    if bitcoin['Volume'] == '-':
        bitcoin['Volume'] = None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1abeeea112ff> in <module>()
#       1 for bitcoin in range(len(bitcoin['Volume'])):
# ----> 2     if bitcoin['Volume'] == '-':
#       3         bitcoin['Volume'] = None
#
# TypeError: 'int' object is not subscriptable

# %%
map(str(bitcoin['Volume']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9f951ce533b9> in <module>()
# ----> 1 map(str(bitcoin['Volume']))
#
# TypeError: 'int' object is not subscriptable

# %%
bitcoin = pd.to_numeric(bitcoin['Volume'].str.replace('-', '').str.replace(',', ''))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-15cd37902d1e> in <module>()
# ----> 1 bitcoin = pd.to_numeric(bitcoin['Volume'].str.replace('-', '').str.replace(',', ''))
#
# TypeError: 'int' object is not subscriptable
